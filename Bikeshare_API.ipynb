# %%
import requests
import json
import pandas as pd
import datetime
from pprint import pprint

# %%
url = "https://maps2.dcgis.dc.gov/dcgis/rest/services/DCGIS_DATA/Transportation_WebMercator/MapServer/5/query?where=1%3D1&outFields=OBJECTID,ID,ADDRESS,TERMINAL_NUMBER,LATITUDE,LONGITUDE,NUMBER_OF_BIKES,NUMBER_OF_EMPTY_DOCKS&outSR=4326&f=json"

response = requests.get(url)
print(response.url)
# Out:
# https://maps2.dcgis.dc.gov/dcgis/rest/services/DCGIS_DATA/Transportation_WebMercator/MapServer/5/query?where=1%3D1&outFields=OBJECTID,ID,ADDRESS,TERMINAL_NUMBER,LATITUDE,LONGITUDE,NUMBER_OF_BIKES,NUMBER_OF_EMPTY_DOCKS&outSR=4326&f=json

# %%
data = response.json()
pprint(data)
#address
# Out:
# {'displayFieldName': 'ADDRESS',
#  'features': [{'attributes': {'ADDRESS': 'Westpark Dr & Leesburg Pike',
#                               'ID': 425,
#                               'LATITUDE': 38.924029999999995,
#                               'LONGITUDE': -77.23595499999999,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 5,
#                               'OBJECTID': 238829989,
#                               'TERMINAL_NUMBER': '32201'},
#                'geometry': {'x': -77.23595735833574, 'y': 38.9240377843289}},
#               {'attributes': {'ADDRESS': 'Tysons One Pl & Chain Bridge Rd',
#                               'ID': 427,
#                               'LATITUDE': 38.919475,
#                               'LONGITUDE': -77.22117899999999,
#                               'NUMBER_OF_BIKES': 3,
#                               'NUMBER_OF_EMPTY_DOCKS': 8,
#                               'OBJECTID': 238829990,
#                               'TERMINAL_NUMBER': '32203'},
#                'geometry': {'x': -77.22118135370994, 'y': 38.91948278395234}},
#               {'attributes': {'ADDRESS': 'Tysons Corner Station',
#                               'ID': 428,
#                               'LATITUDE': 38.920939,
#                               'LONGITUDE': -77.222115,
#                               'NUMBER_OF_BIKES': 4,
#                               'NUMBER_OF_EMPTY_DOCKS': 6,
#                               'OBJECTID': 238829991,
#                               'TERMINAL_NUMBER': '32204'},
#                'geometry': {'x': -77.2221173541538, 'y': 38.920946784260934}},
#               {'attributes': {'ADDRESS': 'Westpark & Jones Branch Dr',
#                               'ID': 429,
#                               'LATITUDE': 38.924437,
#                               'LONGITUDE': -77.217664,
#                               'NUMBER_OF_BIKES': 9,
#                               'NUMBER_OF_EMPTY_DOCKS': 2,
#                               'OBJECTID': 238829992,
#                               'TERMINAL_NUMBER': '32205'},
#                'geometry': {'x': -77.21766635271521, 'y': 38.92444478511608}},
#               {'attributes': {'ADDRESS': 'Jones Branch & Westbranch Dr',
#                               'ID': 430,
#                               'LATITUDE': 38.931911,
#                               'LONGITUDE': -77.219261,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 3,
#                               'OBJECTID': 238829993,
#                               'TERMINAL_NUMBER': '32206'},
#                'geometry': {'x': -77.21926335406067, 'y': 38.931918786378105}},
#               {'attributes': {'ADDRESS': 'Westpark & Park Run Dr',
#                               'ID': 431,
#                               'LATITUDE': 38.928919,
#                               'LONGITUDE': -77.225394,
#                               'NUMBER_OF_BIKES': 7,
#                               'NUMBER_OF_EMPTY_DOCKS': 4,
#                               'OBJECTID': 238829994,
#                               'TERMINAL_NUMBER': '32207'},
#                'geometry': {'x': -77.22539635517155, 'y': 38.9289267855913}},
#               {'attributes': {'ADDRESS': 'Tysons West Transit Center',
#                               'ID': 432,
#                               'LATITUDE': 38.932635999999995,
#                               'LONGITUDE': -77.231825,
#                               'NUMBER_OF_BIKES': 7,
#                               'NUMBER_OF_EMPTY_DOCKS': 4,
#                               'OBJECTID': 238829995,
#                               'TERMINAL_NUMBER': '32208'},
#                'geometry': {'x': -77.23182735745878, 'y': 38.93264378629483}},
#               {'attributes': {'ADDRESS': 'North Shore & Cameron Crescent '
#                                          'Dr/Crescent Apartments',
#                               'ID': 433,
#                               'LATITUDE': 38.970045999999996,
#                               'LONGITUDE': -77.338686,
#                               'NUMBER_OF_BIKES': 4,
#                               'NUMBER_OF_EMPTY_DOCKS': 6,
#                               'OBJECTID': 238829996,
#                               'TERMINAL_NUMBER': '32209'},
#                'geometry': {'x': -77.33868839294841, 'y': 38.97005378959072}},
#               {'attributes': {'ADDRESS': 'Town Center Pkwy & Bowman Towne Dr',
#                               'ID': 434,
#                               'LATITUDE': 38.962523999999995,
#                               'LONGITUDE': -77.361902,
#                               'NUMBER_OF_BIKES': 2,
#                               'NUMBER_OF_EMPTY_DOCKS': 13,
#                               'OBJECTID': 238829997,
#                               'TERMINAL_NUMBER': '32210'},
#                'geometry': {'x': -77.36190439968458, 'y': 38.962531787175976}},
#               {'attributes': {'ADDRESS': 'Reston Regional Library',
#                               'ID': 435,
#                               'LATITUDE': 38.962095,
#                               'LONGITUDE': -77.35881499999999,
#                               'NUMBER_OF_BIKES': 7,
#                               'NUMBER_OF_EMPTY_DOCKS': 8,
#                               'OBJECTID': 238829998,
#                               'TERMINAL_NUMBER': '32211'},
#                'geometry': {'x': -77.35881739896097, 'y': 38.962102787186346}},
#               {'attributes': {'ADDRESS': 'New Dominion Pkwy & Fountain Dr',
#                               'ID': 436,
#                               'LATITUDE': 38.960574,
#                               'LONGITUDE': -77.356324,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 7,
#                               'OBJECTID': 238829999,
#                               'TERMINAL_NUMBER': '32212'},
#                'geometry': {'x': -77.35632639790585, 'y': 38.96058178681448}},
#               {'attributes': {'ADDRESS': 'Sunset Hills & Old Reston Ave',
#                               'ID': 437,
#                               'LATITUDE': 38.955079,
#                               'LONGITUDE': -77.351649,
#                               'NUMBER_OF_BIKES': 10,
#                               'NUMBER_OF_EMPTY_DOCKS': 5,
#                               'OBJECTID': 238830000,
#                               'TERMINAL_NUMBER': '32213'},
#                'geometry': {'x': -77.35165139601372, 'y': 38.95508678588884}},
#               {'attributes': {'ADDRESS': 'Reston Town Center Transit Station',
#                               'ID': 438,
#                               'LATITUDE': 38.957037,
#                               'LONGITUDE': -77.359718,
#                               'NUMBER_OF_BIKES': 4,
#                               'NUMBER_OF_EMPTY_DOCKS': 13,
#                               'OBJECTID': 238830001,
#                               'TERMINAL_NUMBER': '32214'},
#                'geometry': {'x': -77.35972039915302, 'y': 38.957044785968534}},
#               {'attributes': {'ADDRESS': '1st & D St SE',
#                               'ID': 439,
#                               'LATITUDE': 38.884916,
#                               'LONGITUDE': -77.005965,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 13,
#                               'OBJECTID': 238830002,
#                               'TERMINAL_NUMBER': '31643'},
#                'geometry': {'x': -77.00596728445085, 'y': 38.88492378515779}},
#               {'attributes': {'ADDRESS': 'Wiehle Ave & Reston Station Blvd',
#                               'ID': 440,
#                               'LATITUDE': 38.949200000000005,
#                               'LONGITUDE': -77.3368,
#                               'NUMBER_OF_BIKES': 15,
#                               'NUMBER_OF_EMPTY_DOCKS': 4,
#                               'OBJECTID': 238830003,
#                               'TERMINAL_NUMBER': '32215'},
#                'geometry': {'x': -77.33680239156486, 'y': 38.94920778551898}},
#               {'attributes': {'ADDRESS': 'Library St & Freedom Dr',
#                               'ID': 441,
#                               'LATITUDE': 38.959633,
#                               'LONGITUDE': -77.358741,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 12,
#                               'OBJECTID': 238830004,
#                               'TERMINAL_NUMBER': '32216'},
#                'geometry': {'x': -77.3587433989796, 'y': 38.959640786935644}},
#               {'attributes': {'ADDRESS': 'Sunset Hills Rd & Discovery Square',
#                               'ID': 442,
#                               'LATITUDE': 38.95534,
#                               'LONGITUDE': -77.35761099999999,
#                               'NUMBER_OF_BIKES': 7,
#                               'NUMBER_OF_EMPTY_DOCKS': 8,
#                               'OBJECTID': 238830005,
#                               'TERMINAL_NUMBER': '32217'},
#                'geometry': {'x': -77.3576133984017, 'y': 38.9553477859561}},
#               {'attributes': {'ADDRESS': '22nd St & Constitution Ave NW',
#                               'ID': 443,
#                               'LATITUDE': 38.892441,
#                               'LONGITUDE': -77.048947,
#                               'NUMBER_OF_BIKES': 15,
#                               'NUMBER_OF_EMPTY_DOCKS': 8,
#                               'OBJECTID': 238830006,
#                               'TERMINAL_NUMBER': '31292'},
#                'geometry': {'x': -77.04894929796147, 'y': 38.89244878508172}},
#               {'attributes': {'ADDRESS': '61st St & Banks Pl NE',
#                               'ID': 444,
#                               'LATITUDE': 38.891805,
#                               'LONGITUDE': -76.913563,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 8,
#                               'OBJECTID': 238830007,
#                               'TERMINAL_NUMBER': '31714'},
#                'geometry': {'x': -76.91356525600641, 'y': 38.89181278968003}},
#               {'attributes': {'ADDRESS': 'Temporary Rd & Old Reston Ave',
#                               'ID': 445,
#                               'LATITUDE': 38.960083999999995,
#                               'LONGITUDE': -77.353414,
#                               'NUMBER_OF_BIKES': 5,
#                               'NUMBER_OF_EMPTY_DOCKS': 10,
#                               'OBJECTID': 238830008,
#                               'TERMINAL_NUMBER': '32218'},
#                'geometry': {'x': -77.35341639694313, 'y': 38.96009178681771}},
#               {'attributes': {'ADDRESS': 'Reston YMCA',
#                               'ID': 446,
#                               'LATITUDE': 38.955314,
#                               'LONGITUDE': -77.368416,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 9,
#                               'OBJECTID': 238830009,
#                               'TERMINAL_NUMBER': '32219'},
#                'geometry': {'x': -77.36841840151375, 'y': 38.95532178575093}},
#               {'attributes': {'ADDRESS': 'Sunset Hills Rd & Isaac Newton '
#                                          'Square',
#                               'ID': 447,
#                               'LATITUDE': 38.951443,
#                               'LONGITUDE': -77.34037699999999,
#                               'NUMBER_OF_BIKES': 10,
#                               'NUMBER_OF_EMPTY_DOCKS': 1,
#                               'OBJECTID': 238830010,
#                               'TERMINAL_NUMBER': '32220'},
#                'geometry': {'x': -77.34037939252293, 'y': 38.95145078579219}},
#               {'attributes': {'ADDRESS': 'N Lynn St & Fairfax Dr',
#                               'ID': 448,
#                               'LATITUDE': 38.89386,
#                               'LONGITUDE': -77.07086199999999,
#                               'NUMBER_OF_BIKES': 5,
#                               'NUMBER_OF_EMPTY_DOCKS': 10,
#                               'OBJECTID': 238830011,
#                               'TERMINAL_NUMBER': '31917'},
#                'geometry': {'x': -77.0708643050521, 'y': 38.893867784270554}},
#               {'attributes': {'ADDRESS': 'Georgia Ave & Piney Branch Rd NW',
#                               'ID': 449,
#                               'LATITUDE': 38.967504999999996,
#                               'LONGITUDE': -77.027976,
#                               'NUMBER_OF_BIKES': 12,
#                               'NUMBER_OF_EMPTY_DOCKS': 3,
#                               'OBJECTID': 238830012,
#                               'TERMINAL_NUMBER': '31414'},
#                'geometry': {'x': -77.0279782960392, 'y': 38.967512800685164}},
#               {'attributes': {'ADDRESS': 'Greensboro & International Dr',
#                               'ID': 450,
#                               'LATITUDE': 38.923083,
#                               'LONGITUDE': -77.227417,
#                               'NUMBER_OF_BIKES': 4,
#                               'NUMBER_OF_EMPTY_DOCKS': 6,
#                               'OBJECTID': 238830013,
#                               'TERMINAL_NUMBER': '32221'},
#                'geometry': {'x': -77.22741935542966, 'y': 38.92309078436229}},
#               {'attributes': {'ADDRESS': 'Madison & Fairfax St',
#                               'ID': 451,
#                               'LATITUDE': 38.812351,
#                               'LONGITUDE': -77.040691,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 5,
#                               'OBJECTID': 238830014,
#                               'TERMINAL_NUMBER': '31918'},
#                'geometry': {'x': -77.04069329067414, 'y': 38.81235876921673}},
#               {'attributes': {'ADDRESS': 'Sligo Ave & Carroll Ln',
#                               'ID': 452,
#                               'LATITUDE': 38.990874,
#                               'LONGITUDE': -77.016311,
#                               'NUMBER_OF_BIKES': 5,
#                               'NUMBER_OF_EMPTY_DOCKS': 9,
#                               'OBJECTID': 238830015,
#                               'TERMINAL_NUMBER': '32058'},
#                'geometry': {'x': -77.01631329447865, 'y': 38.990881805944156}},
#               {'attributes': {'ADDRESS': '15th & W St NW',
#                               'ID': 453,
#                               'LATITUDE': 38.919086,
#                               'LONGITUDE': -77.034502,
#                               'NUMBER_OF_BIKES': 5,
#                               'NUMBER_OF_EMPTY_DOCKS': 14,
#                               'OBJECTID': 238830016,
#                               'TERMINAL_NUMBER': '31125'},
#                'geometry': {'x': -77.03450429548225, 'y': 38.91909379085842}},
#               {'attributes': {'ADDRESS': '12th St & Pennsylvania Ave SE',
#                               'ID': 454,
#                               'LATITUDE': 38.882489,
#                               'LONGITUDE': -76.990121,
#                               'NUMBER_OF_BIKES': 11,
#                               'NUMBER_OF_EMPTY_DOCKS': 7,
#                               'OBJECTID': 238830017,
#                               'TERMINAL_NUMBER': '31644'},
#                'geometry': {'x': -76.9901232793601, 'y': 38.88249678488278}},
#               {'attributes': {'ADDRESS': '3rd St & Riggs Rd NE',
#                               'ID': 455,
#                               'LATITUDE': 38.957463,
#                               'LONGITUDE': -77.002239,
#                               'NUMBER_OF_BIKES': 13,
#                               'NUMBER_OF_EMPTY_DOCKS': 2,
#                               'OBJECTID': 238830018,
#                               'TERMINAL_NUMBER': '31412'},
#                'geometry': {'x': -77.00224128777154, 'y': 38.957470799633995}},
#               {'attributes': {'ADDRESS': 'Carlin Springs Rd & N Thomas St',
#                               'ID': 456,
#                               'LATITUDE': 38.876695,
#                               'LONGITUDE': -77.112982,
#                               'NUMBER_OF_BIKES': 7,
#                               'NUMBER_OF_EMPTY_DOCKS': 8,
#                               'OBJECTID': 238830019,
#                               'TERMINAL_NUMBER': '31919'},
#                'geometry': {'x': -77.1129843172005, 'y': 38.87670277908287}},
#               {'attributes': {'ADDRESS': 'Towers Crescent Dr & Tysons One Pl',
#                               'ID': 457,
#                               'LATITUDE': 38.915245999999996,
#                               'LONGITUDE': -77.220157,
#                               'NUMBER_OF_BIKES': 4,
#                               'NUMBER_OF_EMPTY_DOCKS': 5,
#                               'OBJECTID': 238830020,
#                               'TERMINAL_NUMBER': '32222'},
#                'geometry': {'x': -77.220159352887, 'y': 38.915253783160594}},
#               {'attributes': {'ADDRESS': '6th & K St NE',
#                               'ID': 458,
#                               'LATITUDE': 38.902877,
#                               'LONGITUDE': -76.99840499999999,
#                               'NUMBER_OF_BIKES': 5,
#                               'NUMBER_OF_EMPTY_DOCKS': 12,
#                               'OBJECTID': 238830021,
#                               'TERMINAL_NUMBER': '31645'},
#                'geometry': {'x': -76.99840728332224, 'y': 38.90288478859323}},
#               {'attributes': {'ADDRESS': 'Pooks Hill Rd & Linden Ave',
#                               'ID': 459,
#                               'LATITUDE': 39.014716,
#                               'LONGITUDE': -77.107143,
#                               'NUMBER_OF_BIKES': 10,
#                               'NUMBER_OF_EMPTY_DOCKS': 5,
#                               'OBJECTID': 238830022,
#                               'TERMINAL_NUMBER': '32057'},
#                'geometry': {'x': -77.10714532389633, 'y': 39.01472380741466}},
#               {'attributes': {'ADDRESS': 'Takoma Park Rec Center',
#                               'ID': 460,
#                               'LATITUDE': 38.98265,
#                               'LONGITUDE': -76.988311,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 9,
#                               'OBJECTID': 238830023,
#                               'TERMINAL_NUMBER': '32059'},
#                'geometry': {'x': -76.98831328480819, 'y': 38.98265780530141}},
#               {'attributes': {'ADDRESS': 'New Hampshire & Kirklynn Ave',
#                               'ID': 461,
#                               'LATITUDE': 38.988101,
#                               'LONGITUDE': -76.988422,
#                               'NUMBER_OF_BIKES': 4,
#                               'NUMBER_OF_EMPTY_DOCKS': 11,
#                               'OBJECTID': 238830024,
#                               'TERMINAL_NUMBER': '32061'},
#                'geometry': {'x': -76.988424285508, 'y': 38.98810880626176}},
#               {'attributes': {'ADDRESS': 'Wheaton Metro/Georgia Ave & Reedie '
#                                          'Dr',
#                               'ID': 462,
#                               'LATITUDE': 39.038340999999996,
#                               'LONGITUDE': -77.051023,
#                               'NUMBER_OF_BIKES': 2,
#                               'NUMBER_OF_EMPTY_DOCKS': 9,
#                               'OBJECTID': 238830025,
#                               'TERMINAL_NUMBER': '32062'},
#                'geometry': {'x': -77.05102530808647, 'y': 39.0383488139607}},
#               {'attributes': {'ADDRESS': 'Amherst Ave & Elkins St',
#                               'ID': 463,
#                               'LATITUDE': 39.044886999999996,
#                               'LONGITUDE': -77.047788,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 9,
#                               'OBJECTID': 238830026,
#                               'TERMINAL_NUMBER': '32063'},
#                'geometry': {'x': -77.047790307363, 'y': 39.044894815279235}},
#               {'attributes': {'ADDRESS': 'Amherst Ave & Prichard Rd',
#                               'ID': 464,
#                               'LATITUDE': 39.035965,
#                               'LONGITUDE': -77.048395,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 9,
#                               'OBJECTID': 238830027,
#                               'TERMINAL_NUMBER': '32064'},
#                'geometry': {'x': -77.04839730684952, 'y': 39.0359728136767}},
#               {'attributes': {'ADDRESS': 'Grandview & Blueridge Ave',
#                               'ID': 465,
#                               'LATITUDE': 39.043272,
#                               'LONGITUDE': -77.053085,
#                               'NUMBER_OF_BIKES': 11,
#                               'NUMBER_OF_EMPTY_DOCKS': 2,
#                               'OBJECTID': 238830028,
#                               'TERMINAL_NUMBER': '32065'},
#                'geometry': {'x': -77.05308730907487, 'y': 39.04327981487296}},
#               {'attributes': {'ADDRESS': 'Windham Ln & Amherst Ave',
#                               'ID': 466,
#                               'LATITUDE': 39.032029,
#                               'LONGITUDE': -77.04735,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 7,
#                               'OBJECTID': 238830029,
#                               'TERMINAL_NUMBER': '32066'},
#                'geometry': {'x': -77.04735230673977, 'y': 39.03203681287975}},
#               {'attributes': {'ADDRESS': 'North Shore Dr & Village Rd',
#                               'ID': 467,
#                               'LATITUDE': 38.970411999999996,
#                               'LONGITUDE': -77.34078699999999,
#                               'NUMBER_OF_BIKES': 9,
#                               'NUMBER_OF_EMPTY_DOCKS': 2,
#                               'OBJECTID': 238830030,
#                               'TERMINAL_NUMBER': '32223'},
#                'geometry': {'x': -77.34078939398587, 'y': 38.97041978934476}},
#               {'attributes': {'ADDRESS': 'Town Center Pkwy & Sunset Hills Rd',
#                               'ID': 468,
#                               'LATITUDE': 38.955171,
#                               'LONGITUDE': -77.36309399999999,
#                               'NUMBER_OF_BIKES': 1,
#                               'NUMBER_OF_EMPTY_DOCKS': 10,
#                               'OBJECTID': 238830031,
#                               'TERMINAL_NUMBER': '32224'},
#                'geometry': {'x': -77.3630964002345, 'y': 38.9551787854817}},
#               {'attributes': {'ADDRESS': '3rd & Underwood St NW',
#                               'ID': 469,
#                               'LATITUDE': 38.968834,
#                               'LONGITUDE': -77.016258,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 11,
#                               'OBJECTID': 238830032,
#                               'TERMINAL_NUMBER': '31413'},
#                'geometry': {'x': -77.01626029261188, 'y': 38.96884180116693}},
#               {'attributes': {'ADDRESS': '18th & Monroe St NE',
#                               'ID': 470,
#                               'LATITUDE': 38.93293,
#                               'LONGITUDE': -76.979517,
#                               'NUMBER_OF_BIKES': 9,
#                               'NUMBER_OF_EMPTY_DOCKS': 10,
#                               'OBJECTID': 238830033,
#                               'TERMINAL_NUMBER': '31521'},
#                'geometry': {'x': -76.97951927895559, 'y': 38.93293779571991}},
#               {'attributes': {'ADDRESS': '7th & E St SW',
#                               'ID': 471,
#                               'LATITUDE': 38.883449999999996,
#                               'LONGITUDE': -77.02174099999999,
#                               'NUMBER_OF_BIKES': 4,
#                               'NUMBER_OF_EMPTY_DOCKS': 15,
#                               'OBJECTID': 238830034,
#                               'TERMINAL_NUMBER': '31294'},
#                'geometry': {'x': -77.02174328921234, 'y': 38.883457783895906}},
#               {'attributes': {'ADDRESS': 'Shady Grove Metro East',
#                               'ID': 472,
#                               'LATITUDE': 39.121327,
#                               'LONGITUDE': -77.164969,
#                               'NUMBER_OF_BIKES': 12,
#                               'NUMBER_OF_EMPTY_DOCKS': 7,
#                               'OBJECTID': 238830035,
#                               'TERMINAL_NUMBER': '32067'},
#                'geometry': {'x': -77.16497134866158, 'y': 39.12133482649551}},
#               {'attributes': {'ADDRESS': 'Potomac & M St NW',
#                               'ID': 473,
#                               'LATITUDE': 38.905367999999996,
#                               'LONGITUDE': -77.06514899999999,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 12,
#                               'OBJECTID': 238830036,
#                               'TERMINAL_NUMBER': '31295'},
#                'geometry': {'x': -77.06515130430819, 'y': 38.90537578675437}},
#               {'attributes': {'ADDRESS': 'Columbia & Ontario Rd NW',
#                               'ID': 474,
#                               'LATITUDE': 38.924088,
#                               'LONGITUDE': -77.040787,
#                               'NUMBER_OF_BIKES': 13,
#                               'NUMBER_OF_EMPTY_DOCKS': 10,
#                               'OBJECTID': 238830037,
#                               'TERMINAL_NUMBER': '31296'},
#                'geometry': {'x': -77.04078929774218, 'y': 38.92409579177801}},
#               {'attributes': {'ADDRESS': 'Washington-Lee High School / N '
#                                          'Stafford St & Generals Way',
#                               'ID': 475,
#                               'LATITUDE': 38.888282,
#                               'LONGITUDE': -77.111066,
#                               'NUMBER_OF_BIKES': 11,
#                               'NUMBER_OF_EMPTY_DOCKS': 4,
#                               'OBJECTID': 238830038,
#                               'TERMINAL_NUMBER': '31920'},
#                'geometry': {'x': -77.11106831746766, 'y': 38.88828978148744}},
#               {'attributes': {'ADDRESS': 'Westover Library / Washington Blvd & '
#                                          'N McKinley Rd',
#                               'ID': 476,
#                               'LATITUDE': 38.886047999999995,
#                               'LONGITUDE': -77.14231699999999,
#                               'NUMBER_OF_BIKES': 9,
#                               'NUMBER_OF_EMPTY_DOCKS': 5,
#                               'OBJECTID': 238830039,
#                               'TERMINAL_NUMBER': '31921'},
#                'geometry': {'x': -77.14231932710514, 'y': 38.886055780257045}},
#               {'attributes': {'ADDRESS': 'Columbia Pike & S Taylor St',
#                               'ID': 477,
#                               'LATITUDE': 38.858523999999996,
#                               'LONGITUDE': -77.10372799999999,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 8,
#                               'OBJECTID': 238830040,
#                               'TERMINAL_NUMBER': '31923'},
#                'geometry': {'x': -77.10373031312253, 'y': 38.85853177605337}},
#               {'attributes': {'ADDRESS': 'Columbus Ave & Tribeca St',
#                               'ID': 478,
#                               'LATITUDE': 39.126000000000005,
#                               'LONGITUDE': -77.1673,
#                               'NUMBER_OF_BIKES': 4,
#                               'NUMBER_OF_EMPTY_DOCKS': 7,
#                               'OBJECTID': 238830041,
#                               'TERMINAL_NUMBER': '32068'},
#                'geometry': {'x': -77.167302349351, 'y': 39.12600782754458}},
#               {'attributes': {'ADDRESS': 'Columbus Ave & Gramercy Blvd',
#                               'ID': 479,
#                               'LATITUDE': 39.123329999999996,
#                               'LONGITUDE': -77.16485999999999,
#                               'NUMBER_OF_BIKES': 3,
#                               'NUMBER_OF_EMPTY_DOCKS': 7,
#                               'OBJECTID': 238830042,
#                               'TERMINAL_NUMBER': '32069'},
#                'geometry': {'x': -77.16486234853109, 'y': 39.123337826822585}},
#               {'attributes': {'ADDRESS': 'Reston Pkwy & Spectrum Dr',
#                               'ID': 480,
#                               'LATITUDE': 38.964208,
#                               'LONGITUDE': -77.35428,
#                               'NUMBER_OF_BIKES': 5,
#                               'NUMBER_OF_EMPTY_DOCKS': 10,
#                               'OBJECTID': 238830043,
#                               'TERMINAL_NUMBER': '32225'},
#                'geometry': {'x': -77.35428239759126, 'y': 38.96421578789972}},
#               {'attributes': {'ADDRESS': 'Key West Ave & Great Seneca Hwy',
#                               'ID': 481,
#                               'LATITUDE': 39.105641999999996,
#                               'LONGITUDE': -77.20385999999999,
#                               'NUMBER_OF_BIKES': 7,
#                               'NUMBER_OF_EMPTY_DOCKS': 4,
#                               'OBJECTID': 238830044,
#                               'TERMINAL_NUMBER': '32070'},
#                'geometry': {'x': -77.20386235953546, 'y': 39.10564982207481}},
#               {'attributes': {'ADDRESS': 'Virginia Ave & 25th St NW',
#                               'ID': 482,
#                               'LATITUDE': 38.8995,
#                               'LONGITUDE': -77.054155,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 11,
#                               'OBJECTID': 238830045,
#                               'TERMINAL_NUMBER': '31297'},
#                'geometry': {'x': -77.05415730013924, 'y': 38.89950778610738}},
#               {'attributes': {'ADDRESS': '15th & M St NW',
#                               'ID': 483,
#                               'LATITUDE': 38.905424,
#                               'LONGITUDE': -77.034674,
#                               'NUMBER_OF_BIKES': 10,
#                               'NUMBER_OF_EMPTY_DOCKS': 9,
#                               'OBJECTID': 238830046,
#                               'TERMINAL_NUMBER': '31298'},
#                'geometry': {'x': -77.03467629472239, 'y': 38.90543178805379}},
#               {'attributes': {'ADDRESS': '11th & Girard St NW',
#                               'ID': 484,
#                               'LATITUDE': 38.925636,
#                               'LONGITUDE': -77.027112,
#                               'NUMBER_OF_BIKES': 13,
#                               'NUMBER_OF_EMPTY_DOCKS': 5,
#                               'OBJECTID': 238830047,
#                               'TERMINAL_NUMBER': '31126'},
#                'geometry': {'x': -77.02711429349442, 'y': 38.92564379206561}},
#               {'attributes': {'ADDRESS': 'Connecticut Ave & R St NW',
#                               'ID': 485,
#                               'LATITUDE': 38.912644,
#                               'LONGITUDE': -77.04563999999999,
#                               'NUMBER_OF_BIKES': 14,
#                               'NUMBER_OF_EMPTY_DOCKS': 3,
#                               'OBJECTID': 238830048,
#                               'TERMINAL_NUMBER': '31299'},
#                'geometry': {'x': -77.04564229817274, 'y': 38.912651789194946}},
#               {'attributes': {'ADDRESS': 'Wilson Blvd & N Troy St',
#                               'ID': 486,
#                               'LATITUDE': 38.892556,
#                               'LONGITUDE': -77.082089,
#                               'NUMBER_OF_BIKES': 5,
#                               'NUMBER_OF_EMPTY_DOCKS': 10,
#                               'OBJECTID': 238830049,
#                               'TERMINAL_NUMBER': '31924'},
#                'geometry': {'x': -77.08209130898008, 'y': 38.89256378349385}},
#               {'attributes': {'ADDRESS': 'Nebraska Ave/AU East Campus',
#                               'ID': 487,
#                               'LATITUDE': 38.936298,
#                               'LONGITUDE': -77.08712799999999,
#                               'NUMBER_OF_BIKES': 2,
#                               'NUMBER_OF_EMPTY_DOCKS': 16,
#                               'OBJECTID': 238830050,
#                               'TERMINAL_NUMBER': '31320'},
#                'geometry': {'x': -77.08713031295792, 'y': 38.93630579245371}},
#               {'attributes': {'ADDRESS': '15th St & Constitution Ave NW',
#                               'ID': 488,
#                               'LATITUDE': 38.892244,
#                               'LONGITUDE': -77.033234,
#                               'NUMBER_OF_BIKES': 11,
#                               'NUMBER_OF_EMPTY_DOCKS': 8,
#                               'OBJECTID': 238830051,
#                               'TERMINAL_NUMBER': '31321'},
#                'geometry': {'x': -77.03323629365177, 'y': 38.892251785628936}},
#               {'attributes': {'ADDRESS': '22nd & H St NW',
#                               'ID': 489,
#                               'LATITUDE': 38.899104,
#                               'LONGITUDE': -77.048946,
#                               'NUMBER_OF_BIKES': 10,
#                               'NUMBER_OF_EMPTY_DOCKS': 6,
#                               'OBJECTID': 238830052,
#                               'TERMINAL_NUMBER': '31127'},
#                'geometry': {'x': -77.04894829854312, 'y': 38.89911178631394}},
#               {'attributes': {'ADDRESS': '23rd & M St NW',
#                               'ID': 490,
#                               'LATITUDE': 38.905302999999996,
#                               'LONGITUDE': -77.050264,
#                               'NUMBER_OF_BIKES': 5,
#                               'NUMBER_OF_EMPTY_DOCKS': 13,
#                               'OBJECTID': 238830053,
#                               'TERMINAL_NUMBER': '31128'},
#                'geometry': {'x': -77.05026629931025, 'y': 38.905310787092525}},
#               {'attributes': {'ADDRESS': 'Corporate Blvd & Omega Dr',
#                               'ID': 491,
#                               'LATITUDE': 39.106971,
#                               'LONGITUDE': -77.192645,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 9,
#                               'OBJECTID': 238830054,
#                               'TERMINAL_NUMBER': '32071'},
#                'geometry': {'x': -77.19264735661072, 'y': 39.10697882231384}},
#               {'attributes': {'ADDRESS': 'Key West Ave & Diamondback Dr',
#                               'ID': 492,
#                               'LATITUDE': 39.106152,
#                               'LONGITUDE': -77.202354,
#                               'NUMBER_OF_BIKES': 5,
#                               'NUMBER_OF_EMPTY_DOCKS': 6,
#                               'OBJECTID': 238830055,
#                               'TERMINAL_NUMBER': '32072'},
#                'geometry': {'x': -77.20235635933712, 'y': 39.106159821989586}},
#               {'attributes': {'ADDRESS': 'Alabama Ave & Stanton Rd SE / Shops '
#                                          'at Park Village',
#                               'ID': 493,
#                               'LATITUDE': 38.84627,
#                               'LONGITUDE': -76.98185,
#                               'NUMBER_OF_BIKES': 7,
#                               'NUMBER_OF_EMPTY_DOCKS': 12,
#                               'OBJECTID': 238830056,
#                               'TERMINAL_NUMBER': '31813'},
#                'geometry': {'x': -76.98185227443123, 'y': 38.84627777809678}},
#               {'attributes': {'ADDRESS': 'Mississippi Ave & 19th St SE / '
#                                          'THEARC',
#                               'ID': 494,
#                               'LATITUDE': 38.84377,
#                               'LONGITUDE': -76.97556999999999,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 11,
#                               'OBJECTID': 238830057,
#                               'TERMINAL_NUMBER': '31814'},
#                'geometry': {'x': -76.97557227270886, 'y': 38.84377777757085}},
#               {'attributes': {'ADDRESS': '19th & Savannah St SE',
#                               'ID': 495,
#                               'LATITUDE': 38.84623,
#                               'LONGITUDE': -76.97703,
#                               'NUMBER_OF_BIKES': 7,
#                               'NUMBER_OF_EMPTY_DOCKS': 4,
#                               'OBJECTID': 238830058,
#                               'TERMINAL_NUMBER': '31815'},
#                'geometry': {'x': -76.97703227312353, 'y': 38.84623777809277}},
#               {'attributes': {'ADDRESS': '4th St & Mississippi Ave SE',
#                               'ID': 496,
#                               'LATITUDE': 38.836,
#                               'LONGITUDE': -77.0009,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 12,
#                               'OBJECTID': 238830059,
#                               'TERMINAL_NUMBER': '31816'},
#                'geometry': {'x': -77.00090227968717, 'y': 38.83600777499512}},
#               {'attributes': {'ADDRESS': '1st & S Capitol St SE / Oxon Run '
#                                          'Trail',
#                               'ID': 497,
#                               'LATITUDE': 38.824481,
#                               'LONGITUDE': -77.00549699999999,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 13,
#                               'OBJECTID': 238830060,
#                               'TERMINAL_NUMBER': '31817'},
#                'geometry': {'x': -77.00549928054335, 'y': 38.82448877259707}},
#               {'attributes': {'ADDRESS': 'Livingston Rd & 3rd St SE',
#                               'ID': 498,
#                               'LATITUDE': 38.82373,
#                               'LONGITUDE': -77.00223,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 7,
#                               'OBJECTID': 238830061,
#                               'TERMINAL_NUMBER': '31818'},
#                'geometry': {'x': -77.00223227942692, 'y': 38.8237377728264}},
#               {'attributes': {'ADDRESS': 'Joliet St & MLK Ave SW/Bald Eagle '
#                                          'Rec Ctr',
#                               'ID': 499,
#                               'LATITUDE': 38.819089999999996,
#                               'LONGITUDE': -77.01033,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 13,
#                               'OBJECTID': 238830062,
#                               'TERMINAL_NUMBER': '31819'},
#                'geometry': {'x': -77.01033228159432, 'y': 38.819097771369535}},
#               {'attributes': {'ADDRESS': '37th & Ely Pl SE / Fort Dupont Ice '
#                                          'Arena',
#                               'ID': 500,
#                               'LATITUDE': 38.883010999999996,
#                               'LONGITUDE': -76.949709,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 7,
#                               'OBJECTID': 238830063,
#                               'TERMINAL_NUMBER': '31715'},
#                'geometry': {'x': -76.94971126678136, 'y': 38.88301878659053}},
#               {'attributes': {'ADDRESS': '15th St & Pennsylvania Ave '
#                                          'NW/Pershing Park',
#                               'ID': 501,
#                               'LATITUDE': 38.89635,
#                               'LONGITUDE': -77.03338,
#                               'NUMBER_OF_BIKES': 9,
#                               'NUMBER_OF_EMPTY_DOCKS': 9,
#                               'OBJECTID': 238830064,
#                               'TERMINAL_NUMBER': '31129'},
#                'geometry': {'x': -77.03338229390866, 'y': 38.8963577860817}},
#               {'attributes': {'ADDRESS': 'Maine Ave & 9th St SW',
#                               'ID': 505,
#                               'LATITUDE': 38.88044,
#                               'LONGITUDE': -77.02523599999999,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 6,
#                               'OBJECTID': 238830065,
#                               'TERMINAL_NUMBER': '31646'},
#                'geometry': {'x': -77.02523829008848, 'y': 38.88044778340904}},
#               {'attributes': {'ADDRESS': 'Lincoln Rd & Seaton Pl NE/Harry '
#                                          'Thomas Rec Center',
#                               'ID': 506,
#                               'LATITUDE': 38.915,
#                               'LONGITUDE': -77.0078,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 11,
#                               'OBJECTID': 238830066,
#                               'TERMINAL_NUMBER': '31523'},
#                'geometry': {'x': -77.0078022869373, 'y': 38.91500779087633}},
#               {'attributes': {'ADDRESS': 'Blueridge Ave & Elkins St',
#                               'ID': 507,
#                               'LATITUDE': 39.04313,
#                               'LONGITUDE': -77.05006,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 8,
#                               'OBJECTID': 238830067,
#                               'TERMINAL_NUMBER': '32073'},
#                'geometry': {'x': -77.05006230789212, 'y': 39.04313781524643}},
#               {'attributes': {'ADDRESS': 'Georgia Ave & Kennedy St NW',
#                               'ID': 508,
#                               'LATITUDE': 38.956739999999996,
#                               'LONGITUDE': -77.02790999999999,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 11,
#                               'OBJECTID': 238830068,
#                               'TERMINAL_NUMBER': '31415'},
#                'geometry': {'x': -77.02791229544769, 'y': 38.95674779840538}},
#               {'attributes': {'ADDRESS': '7th St & Massachusetts Ave NE',
#                               'ID': 509,
#                               'LATITUDE': 38.89222,
#                               'LONGITUDE': -76.99602,
#                               'NUMBER_OF_BIKES': 13,
#                               'NUMBER_OF_EMPTY_DOCKS': 6,
#                               'OBJECTID': 238830069,
#                               'TERMINAL_NUMBER': '31647'},
#                'geometry': {'x': -76.99602228164582, 'y': 38.892227786791665}},
#               {'attributes': {'ADDRESS': 'Anacostia Park',
#                               'ID': 510,
#                               'LATITUDE': 38.873349999999995,
#                               'LONGITUDE': -76.9834,
#                               'NUMBER_OF_BIKES': 9,
#                               'NUMBER_OF_EMPTY_DOCKS': 10,
#                               'OBJECTID': 238830070,
#                               'TERMINAL_NUMBER': '31820'},
#                'geometry': {'x': -76.98340227642365, 'y': 38.87335778312538}},
#               {'attributes': {'ADDRESS': 'Twinbrook Metro',
#                               'ID': 511,
#                               'LATITUDE': 39.062041,
#                               'LONGITUDE': -77.12077599999999,
#                               'NUMBER_OF_BIKES': 12,
#                               'NUMBER_OF_EMPTY_DOCKS': 2,
#                               'OBJECTID': 238830071,
#                               'TERMINAL_NUMBER': '32074'},
#                'geometry': {'x': -77.12077833088267, 'y': 39.062048816156036}},
#               {'attributes': {'ADDRESS': 'White Flint Metro',
#                               'ID': 512,
#                               'LATITUDE': 39.047529999999995,
#                               'LONGITUDE': -77.11287,
#                               'NUMBER_OF_BIKES': 19,
#                               'NUMBER_OF_EMPTY_DOCKS': 6,
#                               'OBJECTID': 238830072,
#                               'TERMINAL_NUMBER': '32075'},
#                'geometry': {'x': -77.11287232810035, 'y': 39.04753781366268}},
#               {'attributes': {'ADDRESS': 'Citadel Ave & McGrath Blvd',
#                               'ID': 513,
#                               'LATITUDE': 39.049,
#                               'LONGITUDE': -77.10933,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 7,
#                               'OBJECTID': 238830073,
#                               'TERMINAL_NUMBER': '32076'},
#                'geometry': {'x': -77.10933232679561, 'y': 39.04900781426987}},
#               {'attributes': {'ADDRESS': 'Rockville Pike & Old Georgetown Rd',
#                               'ID': 514,
#                               'LATITUDE': 39.049765,
#                               'LONGITUDE': -77.11368,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 7,
#                               'OBJECTID': 238830074,
#                               'TERMINAL_NUMBER': '32077'},
#                'geometry': {'x': -77.11368232841404, 'y': 39.0497728142451}},
#               {'attributes': {'ADDRESS': 'Woodglen Dr & Executive Blvd',
#                               'ID': 515,
#                               'LATITUDE': 39.043169999999996,
#                               'LONGITUDE': -77.1135,
#                               'NUMBER_OF_BIKES': 10,
#                               'NUMBER_OF_EMPTY_DOCKS': 6,
#                               'OBJECTID': 238830075,
#                               'TERMINAL_NUMBER': '32078'},
#                'geometry': {'x': -77.1135023276639, 'y': 39.043177812701074}},
#               {'attributes': {'ADDRESS': 'Executive Blvd & E Jefferson St',
#                               'ID': 516,
#                               'LATITUDE': 39.04873,
#                               'LONGITUDE': -77.12570000000001,
#                               'NUMBER_OF_BIKES': 9,
#                               'NUMBER_OF_EMPTY_DOCKS': 6,
#                               'OBJECTID': 238830076,
#                               'TERMINAL_NUMBER': '32079'},
#                'geometry': {'x': -77.12570233212124, 'y': 39.04873781329372}},
#               {'attributes': {'ADDRESS': 'Fishers Ln & Rock Creek Mill Rd',
#                               'ID': 517,
#                               'LATITUDE': 39.0629,
#                               'LONGITUDE': -77.11345399999999,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 7,
#                               'OBJECTID': 238830077,
#                               'TERMINAL_NUMBER': '32080'},
#                'geometry': {'x': -77.11345632911444, 'y': 39.0629078166413}},
#               {'attributes': {'ADDRESS': 'Congressional Ln & E Jefferson St',
#                               'ID': 518,
#                               'LATITUDE': 39.06219,
#                               'LONGITUDE': -77.129235,
#                               'NUMBER_OF_BIKES': 12,
#                               'NUMBER_OF_EMPTY_DOCKS': 2,
#                               'OBJECTID': 238830078,
#                               'TERMINAL_NUMBER': '32081'},
#                'geometry': {'x': -77.12923733364636, 'y': 39.06219781612679}},
# ...
#                               'OBJECTID': 238829961,
#                               'TERMINAL_NUMBER': '31123'},
#                'geometry': {'x': -77.03237729539055, 'y': 38.92529179231776}},
#               {'attributes': {'ADDRESS': 'Potomac Ave & Main Line Blvd',
#                               'ID': 398,
#                               'LATITUDE': 38.822738,
#                               'LONGITUDE': -77.04926499999999,
#                               'NUMBER_OF_BIKES': 5,
#                               'NUMBER_OF_EMPTY_DOCKS': 14,
#                               'OBJECTID': 238829962,
#                               'TERMINAL_NUMBER': '31910'},
#                'geometry': {'x': -77.04926729450548, 'y': 38.822745770725795}},
#               {'attributes': {'ADDRESS': '11th & O St NW',
#                               'ID': 399,
#                               'LATITUDE': 38.908429999999996,
#                               'LONGITUDE': -77.02714,
#                               'NUMBER_OF_BIKES': 9,
#                               'NUMBER_OF_EMPTY_DOCKS': 10,
#                               'OBJECTID': 238829963,
#                               'TERMINAL_NUMBER': '31286'},
#                'geometry': {'x': -77.02714229259936, 'y': 38.90843778891078}},
#               {'attributes': {'ADDRESS': "10th St & L'Enfant Plaza SW",
#                               'ID': 400,
#                               'LATITUDE': 38.884322999999995,
#                               'LONGITUDE': -77.02601,
#                               'NUMBER_OF_BIKES': 4,
#                               'NUMBER_OF_EMPTY_DOCKS': 19,
#                               'OBJECTID': 238829964,
#                               'TERMINAL_NUMBER': '31287'},
#                'geometry': {'x': -77.02601229090885, 'y': 38.88433078421913}},
#               {'attributes': {'ADDRESS': 'Connecticut Ave & Yuma St NW',
#                               'ID': 401,
#                               'LATITUDE': 38.947156,
#                               'LONGITUDE': -77.06511499999999,
#                               'NUMBER_OF_BIKES': 12,
#                               'NUMBER_OF_EMPTY_DOCKS': 7,
#                               'OBJECTID': 238829965,
#                               'TERMINAL_NUMBER': '31318'},
#                'geometry': {'x': -77.06511730699906, 'y': 38.94716379543854}},
#               {'attributes': {'ADDRESS': '2nd St & Massachusetts Ave NE',
#                               'ID': 402,
#                               'LATITUDE': 38.894971999999996,
#                               'LONGITUDE': -77.003135,
#                               'NUMBER_OF_BIKES': 10,
#                               'NUMBER_OF_EMPTY_DOCKS': 10,
#                               'OBJECTID': 238829966,
#                               'TERMINAL_NUMBER': '31641'},
#                'geometry': {'x': -77.00313728425236, 'y': 38.894979787266244}},
#               {'attributes': {'ADDRESS': 'Radford & Osage St',
#                               'ID': 403,
#                               'LATITUDE': 38.828437,
#                               'LONGITUDE': -77.08603099999999,
#                               'NUMBER_OF_BIKES': 11,
#                               'NUMBER_OF_EMPTY_DOCKS': 11,
#                               'OBJECTID': 238829967,
#                               'TERMINAL_NUMBER': '31908'},
#                'geometry': {'x': -77.08603330581245, 'y': 38.82844477035153}},
#               {'attributes': {'ADDRESS': 'East Falls Church Metro/Sycamore St '
#                                          '& 19th St N',
#                               'ID': 404,
#                               'LATITUDE': 38.884859,
#                               'LONGITUDE': -77.155988,
#                               'NUMBER_OF_BIKES': 15,
#                               'NUMBER_OF_EMPTY_DOCKS': 4,
#                               'OBJECTID': 238829968,
#                               'TERMINAL_NUMBER': '31904'},
#                'geometry': {'x': -77.15599033114039, 'y': 38.884866779554855}},
#               {'attributes': {'ADDRESS': 'Kennebec St & 11th St N',
#                               'ID': 405,
#                               'LATITUDE': 38.880992,
#                               'LONGITUDE': -77.135271,
#                               'NUMBER_OF_BIKES': 9,
#                               'NUMBER_OF_EMPTY_DOCKS': 5,
#                               'OBJECTID': 238829969,
#                               'TERMINAL_NUMBER': '31905'},
#                'geometry': {'x': -77.13527332462856, 'y': 38.8809997792136}},
#               {'attributes': {'ADDRESS': 'Commonwealth Ave & Oak St',
#                               'ID': 406,
#                               'LATITUDE': 38.812711,
#                               'LONGITUDE': -77.06171499999999,
#                               'NUMBER_OF_BIKES': 6,
#                               'NUMBER_OF_EMPTY_DOCKS': 11,
#                               'OBJECTID': 238829970,
#                               'TERMINAL_NUMBER': '31906'},
#                'geometry': {'x': -77.06171729752961, 'y': 38.812718768353214}},
#               {'attributes': {'ADDRESS': 'Commonwealth & E Monroe Ave',
#                               'ID': 407,
#                               'LATITUDE': 38.820057999999996,
#                               'LONGITUDE': -77.062821,
#                               'NUMBER_OF_BIKES': 11,
#                               'NUMBER_OF_EMPTY_DOCKS': 4,
#                               'OBJECTID': 238829971,
#                               'TERMINAL_NUMBER': '31913'},
#                'geometry': {'x': -77.06282329789983, 'y': 38.82006576979052}},
#               {'attributes': {'ADDRESS': '4th St & Madison Dr NW',
#                               'ID': 408,
#                               'LATITUDE': 38.890493,
#                               'LONGITUDE': -77.017253,
#                               'NUMBER_OF_BIKES': 2,
#                               'NUMBER_OF_EMPTY_DOCKS': 29,
#                               'OBJECTID': 238829972,
#                               'TERMINAL_NUMBER': '31288'},
#                'geometry': {'x': -77.01725528868047, 'y': 38.89050078572618}},
#               {'attributes': {'ADDRESS': 'Henry Bacon Dr & Lincoln Memorial '
#                                          'Circle NW',
#                               'ID': 409,
#                               'LATITUDE': 38.890544,
#                               'LONGITUDE': -77.049379,
#                               'NUMBER_OF_BIKES': 16,
#                               'NUMBER_OF_EMPTY_DOCKS': 0,
#                               'OBJECTID': 238829973,
#                               'TERMINAL_NUMBER': '31289'},
#                'geometry': {'x': -77.04938129831248, 'y': 38.890551784558404}},
#               {'attributes': {'ADDRESS': '17th St & Independence Ave SW',
#                               'ID': 410,
#                               'LATITUDE': 38.888096999999995,
#                               'LONGITUDE': -77.038325,
#                               'NUMBER_OF_BIKES': 5,
#                               'NUMBER_OF_EMPTY_DOCKS': 14,
#                               'OBJECTID': 238829974,
#                               'TERMINAL_NUMBER': '31290'},
#                'geometry': {'x': -77.03832729484822, 'y': 38.888104784435704}},
#               {'attributes': {'ADDRESS': 'Franklin & S Washington St',
#                               'ID': 411,
#                               'LATITUDE': 38.798133,
#                               'LONGITUDE': -77.0487,
#                               'NUMBER_OF_BIKES': 11,
#                               'NUMBER_OF_EMPTY_DOCKS': 8,
#                               'OBJECTID': 238829975,
#                               'TERMINAL_NUMBER': '31907'},
#                'geometry': {'x': -77.04870229241736, 'y': 38.79814076602267}},
#               {'attributes': {'ADDRESS': 'Mount Vernon Ave & Four Mile Run '
#                                          'Park',
#                               'ID': 412,
#                               'LATITUDE': 38.843422,
#                               'LONGITUDE': -77.064016,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 7,
#                               'OBJECTID': 238829976,
#                               'TERMINAL_NUMBER': '31909'},
#                'geometry': {'x': -77.06401830025858, 'y': 38.843429774314934}},
#               {'attributes': {'ADDRESS': 'New Jersey Ave & L St NW',
#                               'ID': 413,
#                               'LATITUDE': 38.903597999999995,
#                               'LONGITUDE': -77.01397,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 15,
#                               'OBJECTID': 238829977,
#                               'TERMINAL_NUMBER': '31642'},
#                'geometry': {'x': -77.01397228838299, 'y': 38.903605788516096}},
#               {'attributes': {'ADDRESS': 'Mount Vernon Ave & Bruce St',
#                               'ID': 414,
#                               'LATITUDE': 38.841291,
#                               'LONGITUDE': -77.063093,
#                               'NUMBER_OF_BIKES': 5,
#                               'NUMBER_OF_EMPTY_DOCKS': 8,
#                               'OBJECTID': 238829978,
#                               'TERMINAL_NUMBER': '31912'},
#                'geometry': {'x': -77.06309529928437, 'y': 38.841298773809}},
#               {'attributes': {'ADDRESS': 'Lee Center',
#                               'ID': 415,
#                               'LATITUDE': 38.797557,
#                               'LONGITUDE': -77.053766,
#                               'NUMBER_OF_BIKES': 8,
#                               'NUMBER_OF_EMPTY_DOCKS': 7,
#                               'OBJECTID': 238829979,
#                               'TERMINAL_NUMBER': '31914'},
#                'geometry': {'x': -77.05376829426554, 'y': 38.79756476569873}},
#               {'attributes': {'ADDRESS': 'Powhatan St & Bashford Ln',
#                               'ID': 416,
#                               'LATITUDE': 38.818748,
#                               'LONGITUDE': -77.047783,
#                               'NUMBER_OF_BIKES': 4,
#                               'NUMBER_OF_EMPTY_DOCKS': 6,
#                               'OBJECTID': 238829980,
#                               'TERMINAL_NUMBER': '31915'},
#                'geometry': {'x': -77.0477852935404, 'y': 38.818755770233885}},
#               {'attributes': {'ADDRESS': 'Potomac & Swann Ave',
#                               'ID': 417,
#                               'LATITUDE': 38.829544999999996,
#                               'LONGITUDE': -77.047844,
#                               'NUMBER_OF_BIKES': 12,
#                               'NUMBER_OF_EMPTY_DOCKS': 6,
#                               'OBJECTID': 238829981,
#                               'TERMINAL_NUMBER': '31916'},
#                'geometry': {'x': -77.04784629419206, 'y': 38.82955277193647}},
#               {'attributes': {'ADDRESS': '14th & Irving St NW',
#                               'ID': 418,
#                               'LATITUDE': 38.928551999999996,
#                               'LONGITUDE': -77.032224,
#                               'NUMBER_OF_BIKES': 26,
#                               'NUMBER_OF_EMPTY_DOCKS': 5,
#                               'OBJECTID': 238829982,
#                               'TERMINAL_NUMBER': '31124'},
#                'geometry': {'x': -77.0322262953903, 'y': 38.9285597928261}},
#               {'attributes': {'ADDRESS': 'Vermont Ave & I St NW',
#                               'ID': 419,
#                               'LATITUDE': 38.901136,
#                               'LONGITUDE': -77.03445099999999,
#                               'NUMBER_OF_BIKES': 10,
#                               'NUMBER_OF_EMPTY_DOCKS': 15,
#                               'OBJECTID': 238829983,
#                               'TERMINAL_NUMBER': '31291'},
#                'geometry': {'x': -77.03445329465494, 'y': 38.90114378723975}},
#               {'attributes': {'ADDRESS': 'Wisconsin Ave & Brandywine St NW',
#                               'ID': 420,
#                               'LATITUDE': 38.949813,
#                               'LONGITUDE': -77.08021699999999,
#                               'NUMBER_OF_BIKES': 7,
#                               'NUMBER_OF_EMPTY_DOCKS': 18,
#                               'OBJECTID': 238829984,
#                               'TERMINAL_NUMBER': '31319'},
#                'geometry': {'x': -77.0802193117242, 'y': 38.949820795460816}},
#               {'attributes': {'ADDRESS': '24th & R St NE / National Arboretum',
#                               'ID': 421,
#                               'LATITUDE': 38.91263,
#                               'LONGITUDE': -76.97192299999999,
#                               'NUMBER_OF_BIKES': 7,
#                               'NUMBER_OF_EMPTY_DOCKS': 11,
#                               'OBJECTID': 238829985,
#                               'TERMINAL_NUMBER': '31520'},
#                'geometry': {'x': -76.97192527541826, 'y': 38.91263779194528}},
#               {'attributes': {'ADDRESS': 'Division Ave & Foote St NE',
#                               'ID': 422,
#                               'LATITUDE': 38.897407,
#                               'LONGITUDE': -76.925907,
#                               'NUMBER_OF_BIKES': 5,
#                               'NUMBER_OF_EMPTY_DOCKS': 10,
#                               'OBJECTID': 238829986,
#                               'TERMINAL_NUMBER': '31713'},
#                'geometry': {'x': -76.9259092605865, 'y': 38.89741479065978}},
#               {'attributes': {'ADDRESS': '16th & Q St SE / Anacostia HS',
#                               'ID': 423,
#                               'LATITUDE': 38.870695,
#                               'LONGITUDE': -76.982359,
#                               'NUMBER_OF_BIKES': 10,
#                               'NUMBER_OF_EMPTY_DOCKS': 13,
#                               'OBJECTID': 238829987,
#                               'TERMINAL_NUMBER': '31812'},
#                'geometry': {'x': -76.98236127652414, 'y': 38.87070278279686}},
#               {'attributes': {'ADDRESS': 'Spring Hill Metro',
#                               'ID': 424,
#                               'LATITUDE': 38.929261,
#                               'LONGITUDE': -77.24065399999999,
#                               'NUMBER_OF_BIKES': 3,
#                               'NUMBER_OF_EMPTY_DOCKS': 12,
#                               'OBJECTID': 238829988,
#                               'TERMINAL_NUMBER': '32200'},
#                'geometry': {'x': -77.24065636025455, 'y': 38.92926878523479}}],
#  'fieldAliases': {'ADDRESS': 'ADDRESS',
#                   'ID': 'ID',
#                   'LATITUDE': 'LATITUDE',
#                   'LONGITUDE': 'LONGITUDE',
#                   'NUMBER_OF_BIKES': 'NUMBER_OF_BIKES',
#                   'NUMBER_OF_EMPTY_DOCKS': 'NUMBER_OF_EMPTY_DOCKS',
#                   'OBJECTID': 'OBJECTID',
#                   'TERMINAL_NUMBER': 'TERMINAL_NUMBER'},
#  'fields': [{'alias': 'OBJECTID',
#              'name': 'OBJECTID',
#              'type': 'esriFieldTypeOID'},
#             {'alias': 'ID', 'name': 'ID', 'type': 'esriFieldTypeInteger'},
#             {'alias': 'ADDRESS',
#              'length': 100,
#              'name': 'ADDRESS',
#              'type': 'esriFieldTypeString'},
#             {'alias': 'TERMINAL_NUMBER',
#              'length': 25,
#              'name': 'TERMINAL_NUMBER',
#              'type': 'esriFieldTypeString'},
#             {'alias': 'LATITUDE',
#              'name': 'LATITUDE',
#              'type': 'esriFieldTypeDouble'},
#             {'alias': 'LONGITUDE',
#              'name': 'LONGITUDE',
#              'type': 'esriFieldTypeDouble'},
#             {'alias': 'NUMBER_OF_BIKES',
#              'name': 'NUMBER_OF_BIKES',
#              'type': 'esriFieldTypeInteger'},
#             {'alias': 'NUMBER_OF_EMPTY_DOCKS',
#              'name': 'NUMBER_OF_EMPTY_DOCKS',
#              'type': 'esriFieldTypeInteger'}],
#  'geometryType': 'esriGeometryPoint',
#  'spatialReference': {'latestWkid': 4326, 'wkid': 4326}}

# %%
address = []
term_id = []
lat = []
long = []
num_bikes = []
num_empty_docks = []
obj_id = []
term_num = []
time_stamp = []

# %%
now = datetime.datetime.now()
time = pd.Timestamp(now.year,now.month,now.day,now.hour,now.minute)
for index,item in enumerate(data["features"]):
    address.append(data["features"][index]["attributes"]["ADDRESS"])
    term_id.append(data["features"][index]["attributes"]["ID"])
    lat.append(data["features"][index]["attributes"]["LATITUDE"])
    long.append(data["features"][index]["attributes"]["LONGITUDE"])
    num_bikes.append(data["features"][index]["attributes"]["NUMBER_OF_BIKES"])
    num_empty_docks.append(data["features"][index]["attributes"]["NUMBER_OF_EMPTY_DOCKS"])
    obj_id.append(data["features"][index]["attributes"]["OBJECTID"])
    term_num.append(data["features"][index]["attributes"]["TERMINAL_NUMBER"])
    time_stamp.append(time)

# %%
print(f"The first address is {address[0]}.")
# Out:
# The first address is Westpark Dr & Leesburg Pike.

# %%
# build a dataframe from the cities, lon,and pressure lists
biker_data = {"time":time_stamp,"term_id": term_id, "address": address, "lat": lat, "long": long, \
              "num_bikes":num_bikes,"num_empty_docks":num_empty_docks, "obj_id":obj_id,"term_num":term_num}

biker_data = pd.DataFrame(biker_data)
biker_data.head()
# Out:
# Empty DataFrame
# Columns: [time, term_id, address, lat, long, num_bikes, num_empty_docks, obj_id, term_num]
# Index: []

# %%
#with open('bike_data.csv', 'w') as f:
#    biker_data.to_csv(f, header=True,index=False)

# %%
with open('bike_data.csv', 'a') as f:
    biker_data.to_csv(f, header=False,index=False)
